# %% [markdown]
# # MRTR & Tasks\n\n**Created by School of AI**

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent/"src"))
from mcp_course.mrtr import input_required
from mcp_course.tasks import TaskStore
print(input_required("r1",[{"id":"approve"}]))
s=TaskStore(); t=s.create(); print(t.task_id)
