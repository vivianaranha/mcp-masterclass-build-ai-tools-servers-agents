# %% [markdown]
# # Gateway Routing\n\n**Created by School of AI**

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent/"src"))
from mcp_course.gateway import PolicyGateway
g=PolicyGateway({("tools/call","read"):"server"},{("tools/call","read"):{"employee"}}); print(g.route({"Mcp-Method":"tools/call","Mcp-Name":"read"},"u",("employee",)))
